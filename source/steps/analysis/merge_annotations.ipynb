# %%
import os

import pandas as pd
import numpy as np

# %%
base = "D:\\Data\\20241210_Ex0016_HILICZ_LC-DDA_Ecoli_Com20"
mode = "neg"
quant_df = pd.read_csv( os.path.join( base, f"fbmn_{mode}_quant.csv" ) )

# %%
sirius_annotations = os.path.join( base, f"sirius_annotations_{mode}" )
structures_df = pd.read_csv( os.path.join( sirius_annotations ,"structure_identifications.tsv"), sep="\t")

# %%
annot_df = quant_df # pd.concat([quant_df["row ID"], zscores], axis=1, )

def read_filter_sirius( file_path, filter_column, threshold_value:float ) -> pd.DataFrame:
    df = pd.read_csv( file_path, sep="\t")
    df.replace("-Infinity", -np.inf, inplace=True)
    df[filter_column] = df[filter_column].replace(",", ".", regex=True).astype(float)
    solid_df = df.loc[df[filter_column] >= threshold_value]
    return solid_df.sort_values(filter_column, ascending=False)

def merge_sirius_annotations( in_path_dir, filter_columns:dict) -> pd.DataFrame:
    pass
    """
    sirius_formulas = read_filter_sirius( os.path.join( in_path_dir ,"formula_identifications.tsv"),
                                          "ZodiacScore",
                                          filter_columns.get( "ZodiacScore" ) )
    sirius_structures = read_filter_sirius( os.path.join( in_path_dir ,"structure_identifications.tsv"),
                                            "ConfidenceScoreApproximate",
                                            filter_columns.get( "ConfidenceScoreApproximate" ) )
    sirius_denovo_structures = read_filter_sirius( os.path.join( sirius_annotations,"denovo_structure_identifications.tsv"),
                                                   "CSI:FingerIDScore",
                                                   -1000 )
    """

# %%
solid_sirius_formulas = read_filter_sirius( os.path.join( sirius_annotations ,"formula_identifications.tsv"), "ZodiacScore", 0.5)
solid_sirius_formulas
# Out:
#      formulaRank molecularFormula             adduct precursorFormula  \
# 301            1       C11H19N3O6           [M - H]-      C11H18N3O6-
# 141            1       C22H24N4O4           [M - H]-      C22H23N4O4-
# 146            1       C10H14N2O4           [M - H]-      C10H13N2O4-
# 286            1           C4H4O4           [M - H]-          C4H3O4-
# 150            1         C6H13NO2           [M - H]-        C6H12NO2-
# ..           ...              ...                ...              ...
# 216            1        C6H10N2O4           [M - H]-        C6H9N2O4-
# 184            1       C5H13FN2O5           [M - H]-      C5H12FN2O5-
# 53             1       C11H16N4O2           [M - H]-      C11H15N4O2-
# 149            1            C4H9N   [M + CH2O2 - H]-        C5H10NO2-
# 145            1       C12H14N2O2  [M + C2H4O2 - H]-      C14H17N2O4-
#
#      ZodiacScore SiriusScore TreeScore IsotopeScore  numExplainedPeaks  \
# ...

# %%
solid_sirius_structures = read_filter_sirius( os.path.join( sirius_annotations ,"structure_identifications.tsv"), "ConfidenceScoreApproximate", 0.5)
solid_sirius_structures
# Out:
#      structurePerIdRank  formulaRank ConfidenceScoreExact  \
# 202                   1            1                0,962
# 101                   1            1                0,943
# 78                    1            1                0,986
# 87                    1            1                0,985
# 82                    1            1                0,977
# ..                  ...          ...                  ...
# 44                    1            1                0,519
# 215                   1            6                0,516
# 118                   1            1                0,507
# 208                   1            1                0,471
# 156                   1            1                0,922
#
#      ConfidenceScoreApproximate CSI:FingerIDScore ZodiacScore SiriusScore  \
# 202                       0.988           -59,963       1,000      79,617
# 101                       0.988           -21,662       0,974      75,724
# ...

# %%
solid_sirius_denovo_structures = read_filter_sirius( os.path.join( sirius_annotations ,"denovo_structure_identifications.tsv"), "CSI:FingerIDScore", -1000)
solid_sirius_denovo_structures
# Out:
#      structurePerIdRank  formulaRank  CSI:FingerIDScore ModelScore  \
# 211                   1            1             -1.930     -0,068
# 34                    1            1             -1.945     -1,498
# 204                   1            1             -2.237     -0,068
# 14                    1            1             -3.060     -0,263
# 22                    1            1             -3.695     -1,813
# ..                  ...          ...                ...        ...
# 180                   1            4           -319.945     -9,397
# 4                     1            1           -333.909    -21,150
# 102                   1            1           -333.910     -7,057
# 279                   1            1           -342.053     -9,777
# 225                   1            2           -418.972     -9,238
#
#     ZodiacScore SiriusScore molecularFormula    adduct precursorFormula  \
# 211       1,000      88,770         C6H9N3O2  [M - H]-        C6H8N3O2-
# ...
